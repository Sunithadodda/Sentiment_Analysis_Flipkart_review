# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\49151\Downloads\sentiment_Analysis_IN1241064\data.csv')

# %%
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# 3  Quite O. K. , but nowadays  the quality of the...        3
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8518 entries, 0 to 8517
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8508 non-null   object
#  1   Review Title     8508 non-null   object
#  2   Place of Review  8468 non-null   object
#  3   Up Votes         8508 non-null   float64
#  4   Down Votes       8508 non-null   float64
#  5   Month            8053 non-null   object
#  6   Review text      8510 non-null   object
#  7   Ratings          8518 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.5+ KB

# %%
df.isnull().sum()
# Out:
# Reviewer Name       10
# Review Title        10
# Place of Review     50
# Up Votes            10
# Down Votes          10
# Month              465
# Review text          8
# Ratings              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# 3  Quite O. K. , but nowadays  the quality of the...        3
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1

# %%
df['Review text'].fillna(df['Review text'].mode()[0],inplace=True)

# %%
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# 3  Quite O. K. , but nowadays  the quality of the...        3
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Ratings',data=df)
plt.title(' Ratings(Ratings)')
plt.show()

# %%
sentiment = []
for i in df['Ratings']:
    if i > 3:
        sentiment.append('positive')
    elif i < 3:
        sentiment.append('negative')
    else:
        sentiment.append('not')
df['sentiment'] = sentiment

# %%
df['sentiment'].value_counts(normalize=True)
# Out:
# positive    0.801621
# negative    0.126145
# not         0.072234
# Name: sentiment, dtype: float64

# %%
df = df[df.Ratings != 3]

# %%
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 4               ASHIK P A                Over priced
# 5             Baji Sankar      Mind-blowing purchase
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 4                          NaN     147.0        24.0  Apr 2016
# 5   Certified Buyer, Hyderabad     173.0        45.0  Oct 2018
#
#                                          Review text  Ratings sentiment
# 0  Nice product, good quality, but price is now r...        4  positive
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1  negative
# 2  Worst product. Damaged shuttlecocks packed in ...        1  negative
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1  negative
# 5  Good quality product. Delivered on time.READ MORE        5  positive

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Ratings',data=df)
plt.title(' Ratings(Ratings)')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\49151\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\49151\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\49151\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\49151\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\49151\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\49151\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\49151\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\49151\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\49151\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\49151\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\49151\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)

# %%
# !pip install STOPWORDS
# Out:
# Requirement already satisfied: STOPWORDS in c:\users\49151\anaconda3\lib\site-packages (1.0.0)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\49151\anaconda3\lib\site-packages)

# %%
positive = df[df['sentiment']=='positive']

# %%
negative = df[df['sentiment']=='negative']

# %%
comment_words = ''
stopwords = set(STOPWORDS)

for val in positive['Review text']:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
    
wordcloud = WordCloud(width = 600, height = 600,
                background_color ='skyblue',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)    
    
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
comment_words = ''
stopwords = set(STOPWORDS)

for val in negative['Review text']:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
    comment_words += " ".join(tokens)+" "
    
wordcloud = WordCloud(width = 600, height = 600,
                #mask = mask,
                background_color ='red',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)    
    
plt.figure(figsize = (10, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
X=df[['Review text']]

# %%
y=df[['sentiment']]

# %%
from sklearn.model_selection import train_test_split as split

X_train,X_test,y_train,y_test=split(X,y,test_size=0.25,random_state=0)

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
stem = PorterStemmer()

# %%
lemma = WordNetLemmatizer()

# %%
def preprocess(data):
    
    # removes special characters
    sentence = re.sub("[^a-zA-Z]"," ",data)
    
    # converts words to lowercase
    sentence = sentence.lower()
    
    # tokenization
    sentence = sentence.split()
    
    #removes the stop words
    sentence = [word for word in sentence if word not in stopwords.words('english')]
    
    # can apply stem or lemm
    # applying lemmatization
    sentence = [lemma.lemmatize(word) for word in sentence]
    
    sentence=  " ".join(sentence)
    
    return sentence

# %%
X_train= X_train['Review text'].apply(preprocess)

# %%
X_test = X_test['Review text'].apply(preprocess)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
# %time X_train_num = cv.fit_transform(X_train)
# Out:
# Wall time: 57.3 ms

# %%
# %time X_test_num = cv.transform(X_test)
# Out:
# Wall time: 29.2 ms

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(X_train_num, y_train)
# Out:
# C:\Users\49151\anaconda3\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_train_pred = lr_model.predict(X_train_num)

# %%
y_pred=lr_model.predict(X_test_num)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_pred))

print(classification_report(y_test, y_pred))
# Out:
# 0.9235443037974683
#               precision    recall  f1-score   support
#
#     negative       0.82      0.58      0.68       273
#     positive       0.93      0.98      0.96      1702
#
#     accuracy                           0.92      1975
#    macro avg       0.88      0.78      0.82      1975
# weighted avg       0.92      0.92      0.92      1975

# %%
train_score=accuracy_score(y_train,y_train_pred)
train_score
# Out:
# 0.950708980418636

# %%
test_score=accuracy_score(y_pred,y_test)
test_score
# Out:
# 0.9235443037974683

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train_num, y_train)
# Out:
# C:\Users\49151\anaconda3\lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_train_pred = rf_model.predict(X_train_num)
y_pred=lr_model.predict(X_test_num)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_pred))

print(classification_report(y_test, y_pred))
# Out:
# 0.9235443037974683
#               precision    recall  f1-score   support
#
#     negative       0.82      0.58      0.68       273
#     positive       0.93      0.98      0.96      1702
#
#     accuracy                           0.92      1975
#    macro avg       0.88      0.78      0.82      1975
# weighted avg       0.92      0.92      0.92      1975

# %%
test_score=accuracy_score(y_pred,y_test)
test_score
# Out:
# 0.9235443037974683

# %%
from sklearn.naive_bayes import MultinomialNB
nb_model= MultinomialNB()
nb_model.fit(X_train_num,y_train)
# Out:
# C:\Users\49151\anaconda3\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
y_train_pred = nb_model.predict(X_train_num)
y_train_pred
# Out:
# array(['negative', 'positive', 'positive', ..., 'positive', 'positive',
#        'negative'], dtype='<U8')

# %%
y_pred=nb_model.predict(X_test_num)
y_pred
# Out:
# array(['positive', 'positive', 'negative', ..., 'positive', 'positive',
#        'positive'], dtype='<U8')

# %%
test_score=accuracy_score(y_pred,y_test)
test_score
# Out:
# 0.9215189873417722

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[ 551,  250],
#        [  84, 5039]], dtype=int64)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_train, y_train_pred)
actual = np.sum(cm, axis=1).reshape(-1, 1)
cmn = np.round(cm/actual, 2)

sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=nb_model.classes_, yticklabels=nb_model.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted')

# %%
cm = confusion_matrix(y_pred,y_test)
actual = np.sum(cm, axis=1).reshape(-1, 1)
cmn = np.round(cm/actual, 2)

sns.heatmap(cmn, annot=True, fmt='.2f', xticklabels=nb_model.classes_, yticklabels=nb_model.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted')

# %%
from joblib import Memory
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from gensim.models import Word2Vec
from sklearn.metrics import f1_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
cachedir = '.cache'
memory = Memory(location=cachedir, verbose=0)

pipelines = {
    'naive_bayes': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', MultinomialNB())
    ], memory=memory),
    'decision_tree': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', DecisionTreeClassifier())
    ], memory=memory),
    'logistic_regression': Pipeline([
        ('vectorization', CountVectorizer()),
        ('classifier', LogisticRegression())
    ], memory=memory)
}

# Define parameter grid for each algorithm
param_grids = {
    'naive_bayes': [
        {
            'vectorization': [CountVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000], 
            'classifier__alpha' : [1, 10]
        }
    ],
    'decision_tree': [
        {
        'vectorization': [CountVectorizer(),TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000],
            'classifier__max_depth': [None, 5, 10]
        }
    ],
    'logistic_regression': [
        {
            'vectorization': [CountVectorizer(), TfidfVectorizer()],
            'vectorization__max_features' : [1000, 1500, 2000, 5000], 
            'classifier__C': [0.1, 1, 10], 
            'classifier__penalty': ['elasticnet'], 
            'classifier__l1_ratio': [0.4, 0.5, 0.6],
            'classifier__solver': ['saga'],
            'classifier__class_weight': ['balanced']
        }
    ]
}

# Perform GridSearchCV for each algorithm

best_models = {}

for algo in pipelines.keys():
    print("*" * 10, algo, "*" * 10)
    grid_search = GridSearchCV(estimator=pipelines[algo], 
                               param_grid=param_grids[algo], 
                               cv=5, 
                               scoring='f1',  
                               return_train_score=True,
                               verbose=1)
    
    grid_search.fit(X_train, y_train)
    best_models[algo] = grid_search.best_estimator_
    y_pred = grid_search.best_estimator_.predict(X_test)
    f1 = f1_score(y_test, y_pred, pos_label='positive')
    print('F1 Score on Test Data:', f1)
# Out:
# ********** naive_bayes **********
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# F1 Score on Test Data: 0.9529581529581529
# ********** decision_tree **********
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# F1 Score on Test Data: 0.9354933726067747
# ********** logistic_regression **********
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# F1 Score on Test Data: 0.9389587073608617

# %%
for name, model in best_models.items():
    print(f"{name}")
    print(f"{model}")
    print()
# Out:
# naive_bayes
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer(max_features=1000)),
#                 ('classifier', MultinomialNB(alpha=1))])
#
# decision_tree
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer(max_features=1000)),
#                 ('classifier', DecisionTreeClassifier())])
#
# logistic_regression
# Pipeline(memory=Memory(location=.cache\joblib),
#          steps=[('vectorization', CountVectorizer(max_features=1000)),
#                 ('classifier',
#                  LogisticRegression(C=0.1, class_weight='balanced',
#                                     l1_ratio=0.4, penalty='elasticnet',
#                                     solver='saga'))])

# %%
import joblib
import os
from sklearn.metrics import f1_score

# %%
save_dir = '/Users/49151/Downloads/sentiment_Analysis_IN1241064/Models'

for name, model in best_models.items():
    print("*" * 10, name, "*" * 10)
    
    joblib.dump(model, os.path.join(save_dir, f'{name}.pkl'))
    loaded_model = joblib.load(os.path.join(save_dir, f'{name}.pkl'))
    
    # %time y_test_pred = loaded_model.predict(X_test)

    f1 = f1_score(y_test, y_test_pred, pos_label='positive')

    print("F1 Score (Positive Class):", f1)
    print("Model Size:", os.path.getsize(os.path.join(save_dir, f'{name}.pkl')), "Bytes")
# Out:
# ********** naive_bayes **********
# Wall time: 15.6 ms
# F1 Score (Positive Class): 0.9529581529581529
# Model Size: 79815 Bytes
# ********** decision_tree **********
# Wall time: 31.2 ms
# F1 Score (Positive Class): 0.9354933726067747
# Model Size: 204105 Bytes
# ********** logistic_regression **********
# Wall time: 20.7 ms
# F1 Score (Positive Class): 0.9389587073608617
# Model Size: 56042 Bytes
